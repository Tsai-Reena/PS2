# %%
import os
import json
import re
from langchain_community.llms import HuggingFaceEndpoint

os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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' #改為自己的API Token
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"
llm_try = HuggingFaceEndpoint(repo_id=repo_id)


# 載入 sample_data.json 文件
with open('./sample_data.json', 'r', encoding='utf-8') as file:
    sample_data = json.load(file)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to C:\Users\lab418\.cache\huggingface\token
# Login successful

# %%
#sample_data

data = {}
total = []
every = []
for index, item in enumerate(sample_data, start=1):

    every = []
    every.append(index)
    every.append(item.get('店名', ''))
    every.append(item.get('評論者', ''))
    every.append(item.get('評分', ''))
    #total.append(every)
    comment = item.get('評論內容', '')
    txt = llm_try.invoke("請找出下面的opinion feature, 例如:口味，態度，配料，並且列出品項，換算成分數，以[商品名稱,評分]格式輸出一次，滿分100，只用中文"+comment)
    matches = re.findall(r'\[.*?\]', txt)

    # 手動解析匹配到的字符串

    for match in matches:
        temp = every.copy()
        # 去掉兩邊的括號
        match = match[1:-1]
        # 使用逗號分隔元素
        elements = match.split(',')
        # 去除多餘的空格，並將數字轉換為整數
        elements = [e.strip() for e in elements]
        if(len(elements) > 1):
            if(elements[1].isnumeric()):
                elements[1] = int(elements[1])
                print(elements)
                temp.append(elements)
                total.append(temp)
    
                
print(total)
# Out:
# ['星巴克', 85]
# ['7-Eleven', 92]
# ['微風吹', 95]
# ['茶葉線', 78]
# ['麥當勞', 80]
# ['新鮮檸檬榨汁', 30]
# ['Sour Lemon Juice', 40]
# ['Fresh Lemonade', 90]
# ['Homemade Lemonade', 85]
# ['Bottled Lemonade', 70]
# ['Strawberry Lemonade', 80]
# ['小店名', 97]
# ['連鎖店名', 93]
# ['下一家店名', 88]
# ['小店名', 97]
# ['連鎖店名', 93]
# ['下一家店名', 88]
# ['小店名', 97]
# ['Bittersweet Chocolate and Chili Drink', 95]
# ['Matcha and Ginger Drink', 93]
# ['Lemon and Turmeric Drink', 92]
# ['柳橙綠茶', 95]
# ['巧蛋綠茶', 98]
# ['紅茶', 80]
# ['紅茶', 75]
# ['茶湯', 90]
# ['茶', 85]
# ['綠茶', 95]
# ['綠茶', 98]
# ['雕紋綠茶', 70]
# ['紫茶', 80]
# ['綠茶湯', 92]
# ['植物茶', 88]
# ['柳橙綠茶', 98]
# ['巧蛋綠茶', 100]
# ['烤肉', 85]
# ['冰淇淋', 90]
# ['咖啡', 70]
# ['麵線', 95]
# ['甜點', 92]
# ['雞肉堡', 80]
# ['蛋炒饼', 98]
# ['桂花蜜青+仙草的紅外套', 85]
# ['反感口味', 10]
# ['情感化態度', 0]
# ['配料問題', 0]
# ['咖哩', 80]
# ['紅茶', 70]
# ['奶茶', 90]
# ['奶茶', 60]
# ['草莓奶茶', 75]
# ['植物奶茶', 50]
# ['披薩', 95]
# ['紅豆汤', 40]
# ['紫薯湯', 85]
# ['芝士甜甜圈', 98]
# ["['咖哩'", 80]
# ["'紅茶'", 70]
# ["'奶茶'", 90]
# ...

# %%
text_file = open("Output.txt", "w",encoding='utf8')

text_file.write(str(total))

text_file.close()

# %%
# 将列表保存到 JSON 文件中
with open('data.json', 'w', encoding='utf-8') as file:
    json.dump(total, file, ensure_ascii=False, indent=4)

print("已保存到 data.json 文件中")
# Out:
# 数据已保存到 data.json 文件中

# %%
comment2 = "偏中間巷弄底的飲料店～\n古意奶茶🧋微糖微冰 $50\n濃厚奶香 不會很早餐店的感覺\n微糖就夠了不用到半糖！\n有特色 好喝～"

# %%
txt = llm_try.invoke("請找出下面的opinion feature, such as 口味，並且列出品項，換算成分數，以[商品名稱,評分]格式輸出一次，滿分100，"+comment2)

# %%
 
# initializing string

test_str = txt 
# printing original string
print("The original string is : " + test_str)
 
# Extract substrings between brackets
# Using regex
res = re.findall(r'\[.*?\]', test_str)
 
# printing result
print("The element between brackets : " + str(res))
# Out:
# The original string is :
# 這家古意奶茶的口味，我認為是偏中間，因為它有一定程度的甜和淡，但是它不是很甜或很淡。以下是我的評定：
#
# 1. 微糖微冰奶茶, 評分: 65
#
# [微糖微冰奶茶, 65]
#
# 這個品項的甜度很少，可以說是偏淡，但是它還有一定程度的甜味，因此我評分為65。
#
# 2. 濃厚奶香味, 評分: 75
#
# [濃厚奶香味, 75]
#
# 這個品項的口味比較強烈，有一定程度的奶香味，但是它還不會讓人感到過度甜或是早餐店的感覺，因此我評分為75。
#
# 3. 有特色 好喝, 評分: 85
#
# [有特色 好喝, 85]
#
# 這個品項的口感和味道比較特別，而且它很好喝，因此我評分為85。
#
# 總分：225
# [古意奶茶, 225]
#
# 由於總分比滿分100還有一定程度的差異，因此這家古意奶茶的口味被評定為偏中間，但是它仍然很好喝！
#
# The element between brackets : ['[微糖微冰奶茶, 65]', '[濃厚奶香味, 75]', '[有特色 好喝, 85]', '[古意奶茶, 225]']

# %%
matches = re.findall(r'\[.*?\]', txt)

# 手動解析匹配到的字符串
parsed_matches = []
for match in matches:
    # 去掉兩邊的括號
    match = match[1:-1]
    # 使用逗號分隔元素
    elements = match.split(',')
    # 去除多餘的空格，並將數字轉換為整數
    elements = [e.strip() for e in elements]
    if(elements[1].isnumeric()):
        elements[1] = int(elements[1])
    print(elements)
    parsed_matches.append(tuple(elements))

# 打印結果
print("The element between brackets : " + str(parsed_matches))
print(parsed_matches[0][0])
# Out:
# ['微糖微冰奶茶', 65]
# ['濃厚奶香味', 75]
# ['有特色 好喝', 85]
# ['古意奶茶', 225]
# The element between brackets : [('微糖微冰奶茶', 65), ('濃厚奶香味', 75), ('有特色 好喝', 85), ('古意奶茶', 225)]
# 微糖微冰奶茶

# %%
import re
import ast

# 假設 txt 是你的輸入字符串
txt = """
這家古意奶茶的口味，我認為是偏中間，因為它有一定程度的甜和淡，但是它不是很甜或很淡。以下是我的評定：

1. 微糖微冰奶茶, 評分: 65

[微糖微冰奶茶, 65]

這個品項的甜度很少，可以說是偏淡，但是它還有一定程度的甜味，因此我評分為65。

2. 濃厚奶香味, 評分: 75

[濃厚奶香味, 75]

這個品項的口味比較強烈，有一定程度的奶香味，但是它還不會讓人感到過度甜或是早餐店的感覺，因此我評分為75。

3. 有特色 好喝, 評分: 85

[有特色 好喝, 85]

這個品項的口感和味道比較特別，而且它很好喝，因此我評分為85。

總分：225
[古意奶茶, 225]

由於總分比滿分100還有一定程度的差異，因此這家古意奶茶的口味被評定為偏中間，但是它仍然很好喝！
"""

# 打印原始字符串
print("The original string is : " + txt)

# 使用正則表達式提取括號中的內容
matches = re.findall(r'\[.*?\]', txt)

# 去除外層括號並轉換為 Python list
parsed_matches = [ast.literal_eval(match) for match in matches]

# 打印結果
print("The element between brackets : " + str(parsed_matches))
# Out:
# The original string is :
# 這家古意奶茶的口味，我認為是偏中間，因為它有一定程度的甜和淡，但是它不是很甜或很淡。以下是我的評定：
#
# 1. 微糖微冰奶茶, 評分: 65
#
# [微糖微冰奶茶, 65]
#
# 這個品項的甜度很少，可以說是偏淡，但是它還有一定程度的甜味，因此我評分為65。
#
# 2. 濃厚奶香味, 評分: 75
#
# [濃厚奶香味, 75]
#
# 這個品項的口味比較強烈，有一定程度的奶香味，但是它還不會讓人感到過度甜或是早餐店的感覺，因此我評分為75。
#
# 3. 有特色 好喝, 評分: 85
#
# [有特色 好喝, 85]
#
# 這個品項的口感和味道比較特別，而且它很好喝，因此我評分為85。
#
# 總分：225
# [古意奶茶, 225]
#
# 由於總分比滿分100還有一定程度的差異，因此這家古意奶茶的口味被評定為偏中間，但是它仍然很好喝！
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 39
#      36 matches = re.findall(r'\[.*?\]', txt)
#      38 # 去除外層括號並轉換為 Python list
# ---> 39 parsed_matches = [ast.literal_eval(match) for match in matches]
#      41 # 打印結果
#      42 print("The element between brackets : " + str(parsed_matches))
#
# Cell In[37], line 39, in <listcomp>(.0)
#      36 matches = re.findall(r'\[.*?\]', txt)
#      38 # 去除外層括號並轉換為 Python list
# ...

# %%
import re

# 假設 txt 是你的輸入字符串
txt = """
這家古意奶茶的口味，我認為是偏中間，因為它有一定程度的甜和淡，但是它不是很甜或很淡。以下是我的評定：

1. 微糖微冰奶茶, 評分: 65

[微糖微冰奶茶, 65]

這個品項的甜度很少，可以說是偏淡，但是它還有一定程度的甜味，因此我評分為65。

2. 濃厚奶香味, 評分: 75

[濃厚奶香味, 75]

這個品項的口味比較強烈，有一定程度的奶香味，但是它還不會讓人感到過度甜或是早餐店的感覺，因此我評分為75。

3. 有特色 好喝, 評分: 85

[有特色 好喝, 85]

這個品項的口感和味道比較特別，而且它很好喝，因此我評分為85。

總分：225
[古意奶茶, 225]

由於總分比滿分100還有一定程度的差異，因此這家古意奶茶的口味被評定為偏中間，但是它仍然很好喝！
"""

# 打印原始字符串
print("The original string is : " + txt)

# 使用正則表達式提取括號中的內容
matches = re.findall(r'\[.*?\]', txt)

# 手動解析匹配到的字符串
parsed_matches = []
for match in matches:
    # 去掉兩邊的括號
    match = match[1:-1]
    # 使用逗號分隔元素
    elements = match.split(',')
    # 去除多餘的空格，並將數字轉換為整數
    elements = [e.strip() for e in elements]
    elements[1] = int(elements[1])
    parsed_matches.append(tuple(elements))

# 打印結果
print("The element between brackets : " + str(parsed_matches))
# Out:
# The original string is :
# 這家古意奶茶的口味，我認為是偏中間，因為它有一定程度的甜和淡，但是它不是很甜或很淡。以下是我的評定：
#
# 1. 微糖微冰奶茶, 評分: 65
#
# [微糖微冰奶茶, 65]
#
# 這個品項的甜度很少，可以說是偏淡，但是它還有一定程度的甜味，因此我評分為65。
#
# 2. 濃厚奶香味, 評分: 75
#
# [濃厚奶香味, 75]
#
# 這個品項的口味比較強烈，有一定程度的奶香味，但是它還不會讓人感到過度甜或是早餐店的感覺，因此我評分為75。
#
# 3. 有特色 好喝, 評分: 85
#
# [有特色 好喝, 85]
#
# 這個品項的口感和味道比較特別，而且它很好喝，因此我評分為85。
#
# 總分：225
# [古意奶茶, 225]
#
# 由於總分比滿分100還有一定程度的差異，因此這家古意奶茶的口味被評定為偏中間，但是它仍然很好喝！
#
# The element between brackets : [('微糖微冰奶茶', 65), ('濃厚奶香味', 75), ('有特色 好喝', 85), ('古意奶茶', 225)]

# %%
parsed_matches[0][1]
# Out:
# 65
